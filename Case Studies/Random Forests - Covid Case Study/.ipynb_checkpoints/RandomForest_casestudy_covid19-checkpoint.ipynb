# %% [markdown]
# ## Random Forest
#
# Random Forest is an ensemble of Decision Trees. With a few exceptions, a `RandomForestClassifier` has all the hyperparameters of a `DecisionTreeClassifier` (to control how trees are grown), plus all the hyperparameters of a `BaggingClassifier` to control the ensemble itself.
#
# The Random Forest algorithm introduces extra randomness when growing trees; instead of searching for the very best feature when splitting a node, it searches for the best feature among a random subset of features. This results in a greater tree diversity, which (once again) trades a higher bias for a lower variance, generally yielding an overall better model. The following `BaggingClassifier` is roughly equivalent to the previous `RandomForestClassifier`. Run the cell below to visualize a single estimator from a random forest model, using the Iris dataset to classify the data into the appropriate species.

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import export_graphviz
from io import StringIO
from IPython.display import Image
import pydotplus

# %%
# Original code wasn't working (I think because I'm on Windows OS instead of an assumed Linux OS?), so I modified to match a
# previous case study's decision-tree graph output

# Load iris dataset
iris = load_iris()

# Model (can also use single decision tree)
model = RandomForestClassifier(n_estimators=10)

# Train
model.fit(iris.data, iris.target)

# Extract single tree
estimator = model.estimators_[5]

# Export as dot file
dot_data = StringIO()

export_graphviz(estimator, out_file=dot_data, 
                feature_names = iris.feature_names,
                class_names = iris.target_names,
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# Alternatively for class_names use entr_model.classes_
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# Notice how each split seperates the data into buckets of similar observations. This is a single tree and a relatively simple classification dataset, but the same method is used in a more complex dataset with greater depth to the trees.

# %% [markdown]
# ## Coronavirus
# Coronavirus disease (COVID-19) is an infectious disease caused by a new virus.
# The disease causes respiratory illness (like the flu) with symptoms such as a cough, fever, and in more severe cases, difficulty breathing. You can protect yourself by washing your hands frequently, avoiding touching your face, and avoiding close contact (1 meter or 3 feet) with people who are unwell. An outbreak of COVID-19 started in December 2019 and at the time of the creation of this project was continuing to spread throughout the world. Many governments recommended only essential outings to public places and closed most business that do not serve food or sell essential items. An excellent [spatial dashboard](https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6) built by Johns Hopkins shows the daily confirmed cases by country.
#
# This case study was designed to drive home the important role that data science plays in real-world situations like this pandemic. This case study uses the Random Forest Classifier and a dataset from the South Korean cases of COVID-19 provided on [Kaggle](https://www.kaggle.com/kimjihoo/coronavirusdataset) to encourage research on this important topic. The goal of the case study is to build a Random Forest Classifier to predict the 'state' of the patient.

# %% [markdown]
# First, please load the needed packages and modules into Python. Next, load the data into a pandas dataframe for ease of use.

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import plotly.graph_objects as go
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor

# %%
url ='SouthKoreacoronavirusdataset/PatientInfo.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# 1  Jungnang-gu     NaN       overseas inflow              1.0           NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu     NaN       overseas inflow              1.0           NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# 0            75.0         2020-01-22     2020-01-23    2020-02-05
# 1            31.0                NaN     2020-01-30    2020-03-02
# 2            17.0                NaN     2020-01-30    2020-02-19
# 3             9.0         2020-01-26     2020-01-30    2020-02-15
# 4             2.0                NaN     2020-01-31    2020-02-24
#
#   deceased_date     state
# 0           NaN  released
# 1           NaN  released
# 2           NaN  released
# 3           NaN  released
# 4           NaN  released

# %%
df.shape
# Out:
# (2218, 18)

# %%
# Counts of null values 
na_df = pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']>0)]
# Out:
#                VarName  NullCount
# 0              disease       2199
# 1        deceased_date       2186
# 2      infection_order       2176
# 3   symptom_onset_date       2025
# 4        released_date       1995
# 5       contact_number       1807
# 6          infected_by       1749
# 7       infection_case       1055
# 8           global_num        904
# 9           birth_year        454
# 10                 age        261
# 11                 sex        145
# 12      confirmed_date        141
# 13               state         88
# 14                city         65

# %%
# Counts of response variable values
df.state.value_counts()
# Out:
# isolated    1791
# released     307
# deceased      32
# Name: state, dtype: int64

# %% [markdown]
#  **<font color='teal'> Create a new column named 'n_age' which is the calculated age based on the birth year column.</font>**

# %%
df['birth_year'].isna().sum()
# Out:
# 454

# %%
# Create "n_age" column that represents a given person's age today
df['n_age'] = datetime.today().year - df['birth_year']

# Print whether "n_age" has the same number of null values as the feature ("birth_year") which it's derived from
df['n_age'].notna().sum() == df['birth_year'].notna().sum()
# Out:
# True

# %% [markdown]
# ### Handle Missing Values

# %% [markdown]
#  **<font color='teal'> Print the number of missing values by column.</font>**

# %%
df.isna().sum()
# Out:
# patient_id               0
# global_num             904
# sex                    145
# birth_year             454
# age                    261
# country                  0
# province                 0
# city                    65
# disease               2199
# infection_case        1055
# infection_order       2176
# infected_by           1749
# contact_number        1807
# symptom_onset_date    2025
# confirmed_date         141
# released_date         1995
# deceased_date         2186
# state                   88
# n_age                  454
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2218 entries, 0 to 2217
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          2218 non-null   int64
#  1   global_num          1314 non-null   float64
#  2   sex                 2073 non-null   object
#  3   birth_year          1764 non-null   float64
#  4   age                 1957 non-null   object
#  5   country             2218 non-null   object
#  6   province            2218 non-null   object
#  7   city                2153 non-null   object
#  8   disease             19 non-null     object
#  9   infection_case      1163 non-null   object
#  10  infection_order     42 non-null     float64
#  11  infected_by         469 non-null    float64
#  12  contact_number      411 non-null    float64
#  13  symptom_onset_date  193 non-null    object
#  14  confirmed_date      2077 non-null   object
#  15  released_date       223 non-null    object
#  16  deceased_date       32 non-null     object
#  17  state               2130 non-null   object
#  18  n_age               1764 non-null   float64
# dtypes: float64(6), int64(1), object(12)
# memory usage: 329.4+ KB

# %% [markdown]
#  **<font color='teal'> Fill the 'disease' missing values with 0 and remap the True values to 1.</font>**

# %%
df['disease'].fillna(value=0, inplace=True)
df['disease'].replace(True, 1, inplace=True)

# %%
df['disease'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
#  **<font color='teal'> Fill null values in the following columns with their mean: 'global_number','birth_year','infection_order','infected_by'and 'contact_number'</font>**

# %%
cols = ['global_num', 'birth_year', 'infection_order', 'infected_by', 'contact_number']

[df[col].fillna(value=df[col].mean(), inplace=True) for col in cols];

# %%
df.isna().sum()
# Out:
# patient_id               0
# global_num               0
# sex                    145
# birth_year               0
# age                    261
# country                  0
# province                 0
# city                    65
# disease                  0
# infection_case        1055
# infection_order          0
# infected_by              0
# contact_number           0
# symptom_onset_date    2025
# confirmed_date         141
# released_date         1995
# deceased_date         2186
# state                   88
# n_age                  454
# dtype: int64

# %% [markdown]
#  **<font color='teal'> Fill the rest of the missing values with any method.</font>**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2218 entries, 0 to 2217
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          2218 non-null   int64
#  1   global_num          2218 non-null   float64
#  2   sex                 2073 non-null   object
#  3   birth_year          2218 non-null   float64
#  4   age                 1957 non-null   object
#  5   country             2218 non-null   object
#  6   province            2218 non-null   object
#  7   city                2153 non-null   object
#  8   disease             2218 non-null   int64
#  9   infection_case      1163 non-null   object
#  10  infection_order     2218 non-null   float64
#  11  infected_by         2218 non-null   float64
#  12  contact_number      2218 non-null   float64
#  13  symptom_onset_date  193 non-null    object
#  14  confirmed_date      2077 non-null   object
#  15  released_date       223 non-null    object
#  16  deceased_date       32 non-null     object
#  17  state               2130 non-null   object
#  18  n_age               1764 non-null   float64
# dtypes: float64(6), int64(2), object(11)
# memory usage: 329.4+ KB

# %% [markdown]
# ### First I'll change the datatypes of certain features to types I want

# %%
# Create a list of date features
date_features = ['symptom_onset_date','confirmed_date','released_date','deceased_date']

# For each of the date features, change it to dtype datetime
for feature in date_features: df[feature] = pd.to_datetime(df[feature])

# Print the dtypes of the changed features
df[date_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2218 entries, 0 to 2217
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   symptom_onset_date  193 non-null    datetime64[ns]
#  1   confirmed_date      2077 non-null   datetime64[ns]
#  2   released_date       223 non-null    datetime64[ns]
#  3   deceased_date       32 non-null     datetime64[ns]
# dtypes: datetime64[ns](4)
# memory usage: 69.4 KB

# %% [markdown]
# ### Handle the "sex" column

# %%
print('The distribution of m/f in "sex" before handling nulls is: \n\n{}'.format(df['sex'].value_counts(normalize=True)))
# Out:
# The distribution of m/f in "sex" before handling nulls is:
#
# female    0.564882
# male      0.435118
# Name: sex, dtype: float64

# %%
# Replace the "sex" column's null-values with proportionately the same probability as the original distribution of values
sex_dist = df['sex'].value_counts(normalize=True)
sex_missing = df['sex'].isna()
df.loc[sex_missing, 'sex'] = np.random.choice(sex_dist.index, size=len(df[sex_missing]), p=sex_dist.values)

# %%
print(df['sex'].value_counts(normalize=True))

print('\nThe number of null values in "sex" is now: {}'.format(df['sex'].isna().sum()))
# Out:
# female    0.564022
# male      0.435978
# Name: sex, dtype: float64
#
# The number of null values in "sex" is now: 0

# %% [markdown]
# ### Handle the "age" column

# %% [markdown]
# ## You've thus far ignored this feature, eventually you gotta do something with it

# %%
df['age'].value_counts()
# Out:
# 20s     467
# 50s     385
# 40s     303
# 30s     251
# 60s     229
# 70s     117
# 80s      84
# 10s      74
# 0s       29
# 90s      17
# 100s      1
# Name: age, dtype: int64

# %%
pd.Series(df['n_age'].values)
# Out:
# 0       57.0
# 1       34.0
# 2       57.0
# 3       30.0
# 4       29.0
#         ...
# 2213    31.0
# 2214    23.0
# 2215    23.0
# 2216    49.0
# 2217    47.0
# Length: 2218, dtype: float64

# %%
df['age'].value_counts(normalize=True)
# Out:
# 20s     0.238631
# 50s     0.196730
# 40s     0.154829
# 30s     0.128258
# 60s     0.117016
# 70s     0.059785
# 80s     0.042923
# 10s     0.037813
# 0s      0.014819
# 90s     0.008687
# 100s    0.000511
# Name: age, dtype: float64

# %%
df[df['age'].isna()].sample(5)
# Out:
#       patient_id   global_num     sex   birth_year  age country  \
# 867   2000000279  4664.816591  female  1982.000000  NaN   Korea
# 1698  6005000004  4664.816591  female  1974.988662  NaN   Korea
# 1921  6016000010  4664.816591  female  1974.988662  NaN   Korea
# 871   2000000283  8471.000000    male  1996.000000  NaN   Korea
# 1736  6008000011  4664.816591  female  1974.988662  NaN   Korea
#
#               province         city  disease        infection_case  \
# 867        Gyeonggi-do    Yongin-si        0       overseas inflow
# 1698  Gyeongsangbuk-do    Gunwi-gun        0    Shincheonji Church
# 1921  Gyeongsangbuk-do  Yecheon-gun        0                   NaN
# 871        Gyeonggi-do  Seongnam-si        0  contact with patient
# 1736  Gyeongsangbuk-do  Bonghwa-gun        0                   NaN
#
#       infection_order   infected_by  contact_number symptom_onset_date  \
# 867          2.285714  2.600789e+09       24.128954                NaT
# 1698         2.285714  2.600789e+09       24.128954                NaT
# 1921         2.285714  2.600789e+09       24.128954                NaT
# 871          2.285714  2.000000e+09       24.128954                NaT
# 1736         2.285714  2.600789e+09       24.128954                NaT
#
#      confirmed_date released_date deceased_date     state  n_age
# 867      2020-03-17           NaT           NaT       NaN   39.0
# 1698     2020-02-26           NaT           NaT  isolated    NaN
# 1921            NaT           NaT           NaT  isolated    NaN
# 871      2020-03-18           NaT           NaT       NaN   25.0
# 1736            NaT           NaT           NaT  isolated    NaN

# %% [markdown]
# ### Handle the "city" column

# %%
df[df['city'].isna()]
# Out:
#       patient_id   global_num     sex   birth_year  age country  \
# 288   1100000007  4664.816591    male  1994.000000  20s   China
# 383   1200000031    31.000000  female  1959.000000  60s   Korea
# 394   1200000047    47.000000  female  1957.000000  60s   Korea
# 395   1200000048    48.000000  female  1948.000000  70s   Korea
# 396   1200000049    49.000000    male  1962.000000  50s   Korea
# ...          ...          ...     ...          ...  ...     ...
# 463   1300000018  4664.816591    male  1974.988662  60s   Korea
# 1071  5100000001    22.000000    male  1974.000000  40s   Korea
# 2159  6100000031  4664.816591  female  1974.988662  NaN   Korea
# 2160  6100000032  4664.816591  female  1974.988662  NaN   Korea
# 2161  6100000033  4664.816591  female  1974.988662  NaN   Korea
#
#               province city  disease        infection_case  infection_order  \
# 288              Busan  NaN        0    Shincheonji Church         2.285714
# 383              Daegu  NaN        0    Shincheonji Church         2.285714
# 394              Daegu  NaN        0    Shincheonji Church         2.285714
# 395              Daegu  NaN        0    Shincheonji Church         2.285714
# 396              Daegu  NaN        0    Shincheonji Church         2.285714
# ...                ...  ...      ...                   ...              ...
# 463            Gwangju  NaN        0  contact with patient         2.285714
# 1071      Jeollanam-do  NaN        0  contact with patient         2.285714
# 2159  Gyeongsangnam-do  NaN        0                   NaN         2.285714
# 2160  Gyeongsangnam-do  NaN        0                   NaN         2.285714
# 2161  Gyeongsangnam-do  NaN        0                   NaN         2.285714
#
#        infected_by  contact_number symptom_onset_date confirmed_date  \
# 288   2.600789e+09      485.000000                NaT     2020-02-22
# 383   2.600789e+09     1160.000000                NaT     2020-02-18
# 394   1.200000e+09       24.128954                NaT     2020-02-19
# 395   1.200000e+09       24.128954                NaT     2020-02-19
# 396   1.200000e+09       24.128954                NaT     2020-02-19
# ...            ...             ...                ...            ...
# 463   1.300000e+09       13.000000                NaT     2020-03-17
# 1071  1.300000e+09        1.000000                NaT     2020-02-06
# 2159  2.600789e+09       24.128954                NaT     2020-02-26
# 2160  2.600789e+09       24.128954                NaT     2020-02-26
# 2161  2.600789e+09       24.128954                NaT     2020-02-26
#
#      released_date deceased_date     state  n_age
# 288            NaT           NaT  isolated   27.0
# 383            NaT           NaT  isolated   62.0
# 394            NaT           NaT  isolated   64.0
# 395            NaT           NaT  isolated   73.0
# 396            NaT           NaT  isolated   59.0
# ...            ...           ...       ...    ...
# 463            NaT           NaT  isolated    NaN
# 1071    2020-02-15           NaT  released   47.0
# 2159           NaT           NaT  isolated    NaN
# 2160           NaT           NaT  isolated    NaN
# 2161           NaT           NaT  isolated    NaN
#
# [65 rows x 19 columns]

# %%
# Find all observations where "city" is null, then show the count of each observation's province
df[df['city'].isna()]['province'].value_counts()
# Out:
# Daegu               42
# Gwangju             18
# Gyeongsangnam-do     3
# Busan                1
# Jeollanam-do         1
# Name: province, dtype: int64

# %%
def impute_null_city_by_province(province, city):
    
    '''Find the observations where the province is [province]'s indexes, replace those observations'
    null city values with [city] based on index, then print the updated [province] null value counts'''
    
    null_rows = df.loc[(df['province'] == province) & (df['city'].isna())].index

    for idx in null_rows: df.at[idx, 'city'] = city

    print(df[df['city'].isna()]['province'].value_counts())

# %%
# I had some incorrect assumptions which led me to create this function, so I don't need it, but I've kept it here anyways
def correct_wrong_province(current_province, correct_province):
    
    '''Find the observations where the province is [current_province]'s indexes, replace those observations'
    province values with [correct_province] based on index, then print the previous and updated [current_province] counts'''
    
    prev_count = df[(df['province'] == current_province) & (df['city'] == current_province)]['province'].count()
    
    wrong_rows = df.loc[(df['province'] == current_province) & (df['city'] == current_province)].index

    for idx in wrong_rows: df.at[idx, 'province'] = correct_province

    new_count = df[(df['province'] == current_province) & (df['city'] == current_province)]['province'].count()
    
    print('Previous incorrect province count: {}\nNew incorrect province count: {}'.format(prev_count, new_count))

# %% [markdown]
# #### Daegu

# %%
# Daegu is a province and a city, so we'll impute the city with Daegu
impute_null_city_by_province(province='Daegu', city='Daegu')
# Out:
# Gwangju             18
# Gyeongsangnam-do     3
# Jeollanam-do         1
# Busan                1
# Name: province, dtype: int64

# %% [markdown]
# #### Gwangju

# %%
# Gwangju is a province and a city, so we'll impute the city with Gwangju
impute_null_city_by_province(province='Gwangju', city='Gwangju')
# Out:
# Gyeongsangnam-do    3
# Jeollanam-do        1
# Busan               1
# Name: province, dtype: int64

# %% [markdown]
# #### Gyeongsangnam-do

# %%
# We'll impute this observation's null city with its province's capital
impute_null_city_by_province(province='Gyeongsangnam-do', city='Changwon-si')
# Out:
# Jeollanam-do    1
# Busan           1
# Name: province, dtype: int64

# %% [markdown]
# #### Jeollanam-do

# %%
# We'll impute this observation's null city with its province's capital
impute_null_city_by_province(province='Jeollanam-do', city='Yeosu-si')
# Out:
# Busan    1
# Name: province, dtype: int64

# %% [markdown]
# #### Busan

# %%
# Busan is a province and a city, so we'll impute the city with Busan
impute_null_city_by_province(province='Busan', city='Busan')
# Out:
# Series([], Name: province, dtype: int64)

# %% [markdown]
# All done with handling null cities!

# %% [markdown]
# ### Handle the "infection_case" column

# %%
df[df['infection_case'].isna()].sample(5)
# Out:
#       patient_id  global_num     sex  birth_year  age country  \
# 1122  6001000048      1211.0  female      2011.0   0s   Korea
# 414   1200000074        74.0    male      1971.0  40s   Korea
# 1133  6001000059      1219.0  female      1969.0  50s   Korea
# 1585  6001000511      7860.0    male      1997.0  20s   Korea
# 1469  6001000395      6271.0    male      1994.0  20s   Korea
#
#               province          city  disease infection_case  infection_order  \
# 1122  Gyeongsangbuk-do  Gyeongsan-si        0            NaN         2.285714
# 414              Daegu         Daegu        0            NaN         2.285714
# 1133  Gyeongsangbuk-do  Gyeongsan-si        0            NaN         2.285714
# 1585  Gyeongsangbuk-do  Gyeongsan-si        0            NaN         2.285714
# 1469  Gyeongsangbuk-do  Gyeongsan-si        0            NaN         2.285714
#
#        infected_by  contact_number symptom_onset_date confirmed_date  \
# 1122  2.600789e+09       24.128954                NaT     2020-02-26
# 414   2.600789e+09       24.128954                NaT     2020-02-20
# 1133  2.600789e+09        2.000000                NaT     2020-02-26
# 1585  2.600789e+09       24.128954                NaT     2020-03-11
# 1469  2.600789e+09       24.128954                NaT     2020-03-05
#
#      released_date deceased_date     state  n_age
# 1122           NaT           NaT  isolated   10.0
# 414            NaT           NaT  isolated   50.0
# 1133           NaT           NaT  isolated   52.0
# 1585           NaT           NaT  isolated   24.0
# 1469           NaT           NaT  isolated   27.0

# %%
df['infection_case'].unique()
# Out:
# array(['overseas inflow', 'contact with patient', 'Seongdong-gu APT',
#        'etc', "Eunpyeong St. Mary's Hospital", 'Shincheonji Church',
#        'Dongan Church', 'Guro-gu Call Center', 'Onchun Church',
#        'Cheongdo Daenam Hospital', 'Suyeong-gu Kindergarten', nan,
#        'Ministry of Oceans and Fisheries', 'gym facility in Cheonan',
#        'gym facility in Sejong', 'River of Grace Community Church',
#        'Pilgrimage to Israel'], dtype=object)

# %% [markdown]
# It seems like "infection_case" is the feature that denotes whether an observation was tied to a unique outbreak, and so imputing null values with inferred cases would be incorrect, so we'll stick with the standard this dataset's organizers chose, which is "etc".

# %%
print('"etc" currently makes up {}% of infection_case'.format(round((df['infection_case'] == 'etc').sum() / len(df) * 100, 2)))
# Out:
# "etc" currently makes up 9.92% of infection_case

# %%
print('infection_case null value count before .fillna(): {}'.format(df['infection_case'].isna().sum()))
# Out:
# infection_case null value count before .fillna(): 1055

# %%
# Impute all null infection_case observations with "etc"
df['infection_case'].fillna('etc', inplace=True)

# %%
print('infection_case null value count after .fillna(): {}'.format(df['infection_case'].isna().sum()))
# Out:
# infection_case null value count after .fillna(): 0

# %%
print('"etc" now makes up {}% of infection_case'.format(round((df['infection_case'] == 'etc').sum() / len(df) * 100, 2)))
# Out:
# "etc" now makes up 57.48% of infection_case

# %% [markdown]
# ### Handle the "confirmed_date" column

# %%
print('The count of null confirmed_date values is: {}'.format(df['confirmed_date'].isna().sum()))
# Out:
# The count of null confirmed_date values is: 141

# %%
# Here are all of the null confirmed_date observations, I'm paying close attention to the index numbers
# of them so to explore the observations surrounding them
df[df['confirmed_date'].isna()]
# Out:
#       patient_id   global_num     sex   birth_year  age country  \
# 1726  6008000001  4664.816591  female  1974.988662  NaN   Korea
# 1727  6008000002  4664.816591    male  1974.988662  NaN   Korea
# 1728  6008000003  4664.816591    male  1974.988662  NaN   Korea
# 1729  6008000004  4664.816591    male  1974.988662  NaN   Korea
# 1730  6008000005  4664.816591  female  1974.988662  NaN   Korea
# ...          ...          ...     ...          ...  ...     ...
# 1944  6016000033  4664.816591  female  1974.988662  NaN   Korea
# 1945  6016000034  4664.816591    male  1974.988662  NaN   Korea
# 1946  6016000035  4664.816591  female  1974.988662  NaN   Korea
# 1947  6016000036  4664.816591  female  1974.988662  NaN   Korea
# 2136  6109000008  4664.816591    male  1950.000000  70s   Korea
#
#               province         city  disease        infection_case  \
# 1726  Gyeongsangbuk-do  Bonghwa-gun        0                   etc
# 1727  Gyeongsangbuk-do  Bonghwa-gun        0                   etc
# 1728  Gyeongsangbuk-do  Bonghwa-gun        0                   etc
# 1729  Gyeongsangbuk-do  Bonghwa-gun        0                   etc
# 1730  Gyeongsangbuk-do  Bonghwa-gun        0                   etc
# ...                ...          ...      ...                   ...
# 1944  Gyeongsangbuk-do  Yecheon-gun        0                   etc
# 1945  Gyeongsangbuk-do  Yecheon-gun        0                   etc
# 1946  Gyeongsangbuk-do  Yecheon-gun        0                   etc
# 1947  Gyeongsangbuk-do  Yecheon-gun        0                   etc
# 2136  Gyeongsangnam-do   Yangsan-si        0  contact with patient
#
#       infection_order   infected_by  contact_number symptom_onset_date  \
# 1726         2.285714  2.600789e+09       24.128954                NaT
# 1727         2.285714  2.600789e+09       24.128954                NaT
# 1728         2.285714  2.600789e+09       24.128954                NaT
# 1729         2.285714  2.600789e+09       24.128954                NaT
# 1730         2.285714  2.600789e+09       24.128954                NaT
# ...               ...           ...             ...                ...
# 1944         2.285714  2.600789e+09       24.128954                NaT
# 1945         2.285714  2.600789e+09       24.128954                NaT
# 1946         2.285714  2.600789e+09       24.128954                NaT
# 1947         2.285714  2.600789e+09       24.128954                NaT
# 2136         2.000000  1.200000e+09       24.128954                NaT
#
#      confirmed_date released_date deceased_date     state  n_age
# 1726            NaT           NaT           NaT  isolated    NaN
# 1727            NaT           NaT           NaT  isolated    NaN
# 1728            NaT           NaT           NaT  isolated    NaN
# 1729            NaT           NaT           NaT  isolated    NaN
# 1730            NaT           NaT           NaT  isolated    NaN
# ...             ...           ...           ...       ...    ...
# 1944            NaT           NaT           NaT  isolated    NaN
# 1945            NaT           NaT           NaT  isolated    NaN
# 1946            NaT           NaT           NaT  deceased    NaN
# 1947            NaT           NaT           NaT  isolated    NaN
# 2136            NaT           NaT           NaT  isolated   71.0
#
# [141 rows x 19 columns]

# %%
# Here's a set of null observations "fenced in" by non-null observations
df.iloc[1720:1788]
# Out:
#       patient_id   global_num     sex   birth_year  age country  \
# 1720  6006000020  4664.816591  female  1960.000000  60s   Korea
# 1721  6006000021  4664.816591  female  1947.000000  70s   Korea
# 1722  6007000001  4664.816591    male  1960.000000  60s   Korea
# 1723  6007000002  4664.816591  female  1958.000000  60s   Korea
# 1724  6007000003  4664.816591  female  1974.988662  20s   Korea
# ...          ...          ...     ...          ...  ...     ...
# 1783  6008000058  4664.816591    male  1974.988662  NaN   Korea
# 1784  6008000059  4664.816591  female  1974.988662  NaN   Korea
# 1785  6008000060  4664.816591  female  1974.988662  NaN   Korea
# 1786  6009000001  4664.816591  female  1998.000000  20s   Korea
# 1787  6009000002  4664.816591  female  1972.000000  40s   Korea
#
#               province          city  disease        infection_case  \
# 1720  Gyeongsangbuk-do   Gimcheon-si        0                   etc
# 1721  Gyeongsangbuk-do   Gimcheon-si        0                   etc
# 1722  Gyeongsangbuk-do  Mungyeong-si        0                   etc
# 1723  Gyeongsangbuk-do  Mungyeong-si        0  contact with patient
# 1724  Gyeongsangbuk-do  Mungyeong-si        0                   etc
# ...                ...           ...      ...                   ...
# 1783  Gyeongsangbuk-do   Bonghwa-gun        0                   etc
# 1784  Gyeongsangbuk-do   Bonghwa-gun        0                   etc
# 1785  Gyeongsangbuk-do   Bonghwa-gun        0                   etc
# 1786  Gyeongsangbuk-do     Sangju-si        0                   etc
# 1787  Gyeongsangbuk-do     Sangju-si        0                   etc
#
#       infection_order   infected_by  contact_number symptom_onset_date  \
# 1720         2.285714  2.600789e+09       24.128954                NaT
# 1721         2.285714  2.600789e+09       24.128954                NaT
# 1722         2.285714  2.600789e+09       24.128954                NaT
# 1723         2.285714  6.007000e+09       24.128954                NaT
# 1724         2.285714  2.600789e+09       24.128954                NaT
# ...               ...           ...             ...                ...
# 1783         2.285714  2.600789e+09       24.128954                NaT
# 1784         2.285714  2.600789e+09       24.128954                NaT
# 1785         2.285714  2.600789e+09       24.128954                NaT
# 1786         2.285714  2.600789e+09       24.128954                NaT
# 1787         2.285714  2.600789e+09       24.128954                NaT
#
#      confirmed_date released_date deceased_date     state  n_age
# 1720     2020-03-06           NaT           NaT  isolated   61.0
# 1721     2020-03-08           NaT           NaT  isolated   74.0
# 1722     2020-02-21           NaT           NaT  isolated   61.0
# 1723     2020-02-21           NaT           NaT  isolated   63.0
# 1724     2020-02-23           NaT           NaT  isolated    NaN
# ...             ...           ...           ...       ...    ...
# 1783            NaT           NaT           NaT  isolated    NaN
# 1784            NaT           NaT           NaT  isolated    NaN
# 1785            NaT           NaT           NaT  isolated    NaN
# 1786     2020-02-20           NaT           NaT  isolated   23.0
# 1787     2020-02-23           NaT           NaT  isolated   49.0
#
# [68 rows x 19 columns]

# %%
# Here's another set of null observations "fenced in" by non-null observations
df.iloc[1910:1970]
# Out:
#       patient_id   global_num     sex   birth_year  age country  \
# 1910  6015000035  6309.000000    male  1974.988662  70s   Korea
# 1911  6015000036  6769.000000  female  1974.988662  70s   Korea
# 1912  6016000001  4664.816591  female  1974.988662  50s   Korea
# 1913  6016000002  4664.816591    male  1974.988662  40s   Korea
# 1914  6016000003  4664.816591    male  1974.988662  20s   Korea
# 1915  6016000004  4664.816591  female  1974.988662  50s   Korea
# 1916  6016000005  4664.816591    male  1974.988662  50s   Korea
# 1917  6016000006  4664.816591    male  1974.988662  60s   Korea
# 1918  6016000007  4664.816591    male  1974.988662  NaN   Korea
# 1919  6016000008  4664.816591  female  1974.988662  NaN   Korea
# 1920  6016000009  4664.816591  female  1974.988662  NaN   Korea
# 1921  6016000010  4664.816591  female  1974.988662  NaN   Korea
# 1922  6016000011  4664.816591    male  1974.988662  NaN   Korea
# 1923  6016000012  4664.816591    male  1974.988662  NaN   Korea
# 1924  6016000013  4664.816591    male  1974.988662  NaN   Korea
# 1925  6016000014  4664.816591    male  1974.988662  NaN   Korea
# 1926  6016000015  4664.816591    male  1974.988662  NaN   Korea
# 1927  6016000016  4664.816591    male  1974.988662  NaN   Korea
# 1928  6016000017  4664.816591  female  1974.988662  NaN   Korea
# 1929  6016000018  4664.816591    male  1974.988662  NaN   Korea
# 1930  6016000019  4664.816591  female  1974.988662  NaN   Korea
# 1931  6016000020  4664.816591    male  1974.988662  NaN   Korea
# 1932  6016000021  4664.816591  female  1974.988662  NaN   Korea
# 1933  6016000022  4664.816591  female  1974.988662  NaN   Korea
# 1934  6016000023  4664.816591  female  1974.988662  NaN   Korea
# 1935  6016000024  4664.816591  female  1974.988662  NaN   Korea
# 1936  6016000025  4664.816591  female  1974.988662  NaN   Korea
# 1937  6016000026  4664.816591  female  1974.988662  NaN   Korea
# 1938  6016000027  4664.816591    male  1974.988662  NaN   Korea
# 1939  6016000028  4664.816591    male  1974.988662  NaN   Korea
# 1940  6016000029  4664.816591  female  1974.988662  NaN   Korea
# 1941  6016000030  4664.816591    male  1974.988662  NaN   Korea
# 1942  6016000031  4664.816591    male  1974.988662  NaN   Korea
# 1943  6016000032  4664.816591    male  1974.988662  NaN   Korea
# 1944  6016000033  4664.816591  female  1974.988662  NaN   Korea
# 1945  6016000034  4664.816591    male  1974.988662  NaN   Korea
# 1946  6016000035  4664.816591  female  1974.988662  NaN   Korea
# 1947  6016000036  4664.816591  female  1974.988662  NaN   Korea
# 1948  6019000001  4664.816591  female  1967.000000  50s   Korea
# 1949  6019000002  4664.816591  female  1944.000000  70s   Korea
# 1950  6019000003  4664.816591  female  1961.000000  50s   Korea
# 1951  6019000004  4664.816591  female  1962.000000  50s   Korea
# 1952  6019000005  4664.816591    male  1947.000000  70s   Korea
# 1953  6019000006  4664.816591    male  1961.000000  50s   Korea
# 1954  6019000007  4664.816591    male  1952.000000  60s   Korea
# 1955  6019000008  4664.816591  female  1964.000000  50s   Korea
# 1956  6019000009  4664.816591  female  1969.000000  50s   Korea
# 1957  6019000010  4664.816591    male  1953.000000  60s   Korea
# 1958  6019000011  4664.816591  female  1965.000000  50s   Korea
# 1959  6019000012  4664.816591  female  1943.000000  70s   Korea
# 1960  6019000013  4664.816591  female  1960.000000  60s   Korea
# 1961  6019000014  4664.816591  female  1959.000000  60s   Korea
# 1962  6019000015  4664.816591  female  1960.000000  60s   Korea
# 1963  6019000016  4664.816591  female  1951.000000  60s   Korea
# 1964  6019000017  4664.816591  female  1955.000000  60s   Korea
# 1965  6019000018  4664.816591  female  1963.000000  50s   Korea
# 1966  6019000019  4664.816591  female  1951.000000  60s   Korea
# 1967  6019000020  4664.816591    male  1991.000000  20s   Korea
# 1968  6019000021  4664.816591    male  1993.000000  20s   Korea
# 1969  6019000022  4664.816591  female  1951.000000  60s   Korea
#
#               province           city  disease        infection_case  \
# 1910  Gyeongsangbuk-do  Yeongcheon-si        0                   etc
# 1911  Gyeongsangbuk-do  Yeongcheon-si        0  contact with patient
# 1912  Gyeongsangbuk-do    Yecheon-gun        0  Pilgrimage to Israel
# 1913  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1914  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1915  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1916  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1917  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1918  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1919  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1920  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1921  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1922  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1923  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1924  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1925  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1926  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1927  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1928  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1929  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1930  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1931  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1932  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1933  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1934  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1935  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1936  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1937  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1938  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1939  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1940  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1941  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1942  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1943  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1944  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1945  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1946  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1947  Gyeongsangbuk-do    Yecheon-gun        0                   etc
# 1948  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1949  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1950  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1951  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1952  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1953  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1954  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1955  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1956  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1957  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1958  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1959  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1960  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1961  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1962  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1963  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1964  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1965  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1966  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1967  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1968  Gyeongsangbuk-do    Uiseong-gun        0                   etc
# 1969  Gyeongsangbuk-do    Uiseong-gun        0                   etc
#
#       infection_order   infected_by  contact_number symptom_onset_date  \
# 1910         2.285714  2.600789e+09       24.128954                NaT
# 1911         2.285714  2.600789e+09       24.128954                NaT
# 1912         2.285714  2.600789e+09       24.128954                NaT
# 1913         2.285714  2.600789e+09       24.128954                NaT
# 1914         2.285714  2.600789e+09       24.128954                NaT
# 1915         2.285714  2.600789e+09       24.128954                NaT
# 1916         2.285714  2.600789e+09       24.128954                NaT
# 1917         2.285714  2.600789e+09       24.128954                NaT
# 1918         2.285714  2.600789e+09       24.128954                NaT
# 1919         2.285714  2.600789e+09       24.128954                NaT
# 1920         2.285714  2.600789e+09       24.128954                NaT
# 1921         2.285714  2.600789e+09       24.128954                NaT
# 1922         2.285714  2.600789e+09       24.128954                NaT
# 1923         2.285714  2.600789e+09       24.128954                NaT
# 1924         2.285714  2.600789e+09       24.128954                NaT
# 1925         2.285714  2.600789e+09       24.128954                NaT
# 1926         2.285714  2.600789e+09       24.128954                NaT
# 1927         2.285714  2.600789e+09       24.128954                NaT
# 1928         2.285714  2.600789e+09       24.128954                NaT
# 1929         2.285714  2.600789e+09       24.128954                NaT
# 1930         2.285714  2.600789e+09       24.128954                NaT
# 1931         2.285714  2.600789e+09       24.128954                NaT
# 1932         2.285714  2.600789e+09       24.128954                NaT
# 1933         2.285714  2.600789e+09       24.128954                NaT
# 1934         2.285714  2.600789e+09       24.128954                NaT
# 1935         2.285714  2.600789e+09       24.128954                NaT
# 1936         2.285714  2.600789e+09       24.128954                NaT
# 1937         2.285714  2.600789e+09       24.128954                NaT
# 1938         2.285714  2.600789e+09       24.128954                NaT
# 1939         2.285714  2.600789e+09       24.128954                NaT
# 1940         2.285714  2.600789e+09       24.128954                NaT
# 1941         2.285714  2.600789e+09       24.128954                NaT
# 1942         2.285714  2.600789e+09       24.128954                NaT
# 1943         2.285714  2.600789e+09       24.128954                NaT
# 1944         2.285714  2.600789e+09       24.128954                NaT
# 1945         2.285714  2.600789e+09       24.128954                NaT
# 1946         2.285714  2.600789e+09       24.128954                NaT
# 1947         2.285714  2.600789e+09       24.128954                NaT
# 1948         2.285714  2.600789e+09       24.128954                NaT
# 1949         2.285714  2.600789e+09       24.128954                NaT
# 1950         2.285714  2.600789e+09       24.128954                NaT
# 1951         2.285714  2.600789e+09       24.128954                NaT
# 1952         2.285714  2.600789e+09       24.128954                NaT
# 1953         2.285714  2.600789e+09       24.128954                NaT
# 1954         2.285714  2.600789e+09       24.128954                NaT
# 1955         2.285714  2.600789e+09       24.128954                NaT
# 1956         2.285714  2.600789e+09       24.128954                NaT
# 1957         2.285714  2.600789e+09       24.128954                NaT
# 1958         2.285714  2.600789e+09       24.128954                NaT
# 1959         2.285714  2.600789e+09       24.128954                NaT
# 1960         2.285714  2.600789e+09       24.128954                NaT
# 1961         2.285714  2.600789e+09       24.128954                NaT
# 1962         2.285714  2.600789e+09       24.128954                NaT
# 1963         2.285714  2.600789e+09       24.128954                NaT
# 1964         2.285714  2.600789e+09       24.128954                NaT
# 1965         2.285714  2.600789e+09       24.128954                NaT
# 1966         2.285714  2.600789e+09       24.128954                NaT
# 1967         2.285714  2.600789e+09       24.128954                NaT
# 1968         2.285714  2.600789e+09       24.128954                NaT
# 1969         2.285714  2.600789e+09       24.128954                NaT
#
#      confirmed_date released_date deceased_date     state  n_age
# 1910     2020-03-06           NaT    2020-03-07  deceased    NaN
# 1911     2020-03-06           NaT           NaT  isolated    NaN
# 1912     2020-02-21    2020-03-11           NaT  released    NaN
# 1913     2020-02-24           NaT           NaT  isolated    NaN
# 1914     2020-03-01    2020-03-10           NaT  released    NaN
# 1915     2020-03-04           NaT           NaT  isolated    NaN
# 1916     2020-03-04           NaT           NaT  isolated    NaN
# 1917     2020-03-06           NaT           NaT  isolated    NaN
# 1918            NaT           NaT           NaT  isolated    NaN
# 1919            NaT           NaT           NaT  isolated    NaN
# 1920            NaT           NaT           NaT  isolated    NaN
# 1921            NaT           NaT           NaT  isolated    NaN
# 1922            NaT           NaT           NaT  isolated    NaN
# 1923            NaT           NaT           NaT  isolated    NaN
# 1924            NaT           NaT           NaT  isolated    NaN
# 1925            NaT           NaT           NaT  isolated    NaN
# 1926            NaT           NaT           NaT  isolated    NaN
# 1927            NaT           NaT           NaT  isolated    NaN
# 1928            NaT           NaT           NaT  isolated    NaN
# 1929            NaT           NaT           NaT  isolated    NaN
# 1930            NaT           NaT           NaT  isolated    NaN
# 1931            NaT           NaT           NaT  isolated    NaN
# 1932            NaT           NaT           NaT  isolated    NaN
# 1933            NaT           NaT           NaT  isolated    NaN
# 1934            NaT           NaT           NaT  isolated    NaN
# 1935            NaT           NaT           NaT  isolated    NaN
# 1936            NaT           NaT           NaT  isolated    NaN
# 1937            NaT           NaT           NaT  isolated    NaN
# 1938            NaT           NaT           NaT  isolated    NaN
# 1939            NaT           NaT           NaT  isolated    NaN
# 1940            NaT           NaT           NaT  isolated    NaN
# 1941            NaT           NaT           NaT  isolated    NaN
# 1942            NaT           NaT           NaT  isolated    NaN
# 1943            NaT           NaT           NaT  isolated    NaN
# 1944            NaT           NaT           NaT  isolated    NaN
# 1945            NaT           NaT           NaT  isolated    NaN
# 1946            NaT           NaT           NaT  deceased    NaN
# 1947            NaT           NaT           NaT  isolated    NaN
# 1948     2020-02-22           NaT           NaT  isolated   54.0
# 1949     2020-02-22           NaT           NaT  isolated   77.0
# 1950     2020-02-22           NaT           NaT  isolated   60.0
# 1951     2020-02-22           NaT           NaT  isolated   59.0
# 1952     2020-02-22           NaT           NaT  isolated   74.0
# 1953     2020-02-22           NaT           NaT  isolated   60.0
# 1954     2020-02-22           NaT           NaT  isolated   69.0
# 1955     2020-02-22           NaT           NaT  isolated   57.0
# 1956     2020-02-22           NaT           NaT  isolated   52.0
# 1957     2020-02-23           NaT           NaT  isolated   68.0
# 1958     2020-02-23           NaT           NaT  isolated   56.0
# 1959     2020-02-23           NaT           NaT  isolated   78.0
# 1960     2020-02-23           NaT           NaT  isolated   61.0
# 1961     2020-02-23           NaT           NaT  isolated   62.0
# 1962     2020-02-23           NaT           NaT  isolated   61.0
# 1963     2020-02-23           NaT           NaT  isolated   70.0
# 1964     2020-02-23           NaT           NaT  isolated   66.0
# 1965     2020-02-23           NaT           NaT  isolated   58.0
# 1966     2020-02-23           NaT           NaT  isolated   70.0
# 1967     2020-02-24           NaT           NaT  isolated   30.0
# 1968     2020-02-25           NaT           NaT  isolated   28.0
# 1969     2020-02-25           NaT           NaT  isolated   70.0

# %% [markdown]
# By searching through the null confirmed_date observations it's apparent that they share the same city as the observations that precede them.
#
# With this, I'm going to use forward-filling to impute the same confirmed_date as the previous non-null confirmed_date entry.

# %%
# Impute the null values with the most recent non-null value before them, as explained directly above
df['confirmed_date'].fillna(method='ffill', inplace=True)

# %%
print('The count of null confirmed_date values is now: {}'.format(df['confirmed_date'].isna().sum()))
# Out:
# The count of null confirmed_date values is now: 0

# %% [markdown]
# ### Handle the "symptom_onset_date" column

# %%
print('The count of null symptom_onset_date values is: {}'.format(df['symptom_onset_date'].isna().sum()))
# Out:
# The count of null symptom_onset_date values is: 2025

# %% [markdown]
# So just about every value in symptom_onset_date is null, presumably no one had a confident enough guess to fill in this information, or maybe it wasn't an important enough metric to measure most of the time. One way or another, it's vastly null!

# %%
df['symptom_onset_date'].unique()
# Out:
# array(['2020-01-22T00:00:00.000000000',                           'NaT',
#        '2020-01-26T00:00:00.000000000', '2020-02-06T00:00:00.000000000',
#        '2020-02-11T00:00:00.000000000', '2020-02-21T00:00:00.000000000',
#        '2020-02-19T00:00:00.000000000', '2020-02-24T00:00:00.000000000',
#        '2020-02-25T00:00:00.000000000', '2020-02-23T00:00:00.000000000',
#        '2020-02-26T00:00:00.000000000', '2020-02-20T00:00:00.000000000',
#        '2020-02-27T00:00:00.000000000', '2020-02-18T00:00:00.000000000',
#        '2020-03-01T00:00:00.000000000', '2020-03-02T00:00:00.000000000',
#        '2020-03-06T00:00:00.000000000', '2020-03-04T00:00:00.000000000',
#        '2020-02-28T00:00:00.000000000', '2020-03-05T00:00:00.000000000',
#        '2020-03-07T00:00:00.000000000', '2020-02-29T00:00:00.000000000',
#        '2020-03-08T00:00:00.000000000', '2020-03-09T00:00:00.000000000',
#        '2020-03-10T00:00:00.000000000', '2020-03-11T00:00:00.000000000',
#        '2020-03-12T00:00:00.000000000', '2020-03-15T00:00:00.000000000',
#        '2020-03-13T00:00:00.000000000', '2020-03-16T00:00:00.000000000',
#        '2020-02-15T00:00:00.000000000', '2020-01-27T00:00:00.000000000',
#        '2020-01-19T00:00:00.000000000', '2020-01-31T00:00:00.000000000',
#        '2020-02-22T00:00:00.000000000', '2020-03-03T00:00:00.000000000',
#        '2020-03-17T00:00:00.000000000', '2020-03-14T00:00:00.000000000',
#        '2020-02-13T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df[df['symptom_onset_date'].isna()]
# Out:
#       patient_id   global_num     sex  birth_year  age country  \
# 1     1000000002     5.000000    male      1987.0  30s   Korea
# 2     1000000003     6.000000    male      1964.0  50s   Korea
# 4     1000000005     9.000000  female      1992.0  20s   Korea
# 5     1000000006    10.000000  female      1966.0  50s   Korea
# 6     1000000007    11.000000    male      1995.0  20s   Korea
# ...          ...          ...     ...         ...  ...     ...
# 2213  6100000085  4664.816591    male      1990.0  30s   Korea
# 2214  7000000001   139.000000    male      1998.0  20s   Korea
# 2215  7000000002   222.000000  female      1998.0  20s   Korea
# 2216  7000000003  4345.000000  female      1972.0  40s   Korea
# 2217  7000000004  5534.000000    male      1974.0  40s   Korea
#
#               province         city  disease        infection_case  \
# 1                Seoul  Jungnang-gu        0       overseas inflow
# 2                Seoul    Jongno-gu        0  contact with patient
# 4                Seoul  Seongbuk-gu        0  contact with patient
# 5                Seoul    Jongno-gu        0  contact with patient
# 6                Seoul    Jongno-gu        0  contact with patient
# ...                ...          ...      ...                   ...
# 2213  Gyeongsangnam-do  Changwon-si        0                   etc
# 2214           Jeju-do      Jeju-do        0                   etc
# 2215           Jeju-do      Jeju-do        0                   etc
# 2216           Jeju-do          etc        0                   etc
# 2217           Jeju-do      Jeju-do        0                   etc
#
#       infection_order   infected_by  contact_number symptom_onset_date  \
# 1            1.000000  2.600789e+09       31.000000                NaT
# 2            2.000000  2.002000e+09       17.000000                NaT
# 4            2.000000  1.000000e+09        2.000000                NaT
# 5            3.000000  1.000000e+09       43.000000                NaT
# 6            3.000000  1.000000e+09        0.000000                NaT
# ...               ...           ...             ...                ...
# 2213         2.285714  2.600789e+09       24.128954                NaT
# 2214         2.285714  2.600789e+09       87.000000                NaT
# 2215         2.285714  2.600789e+09       84.000000                NaT
# 2216         2.285714  2.600789e+09       21.000000                NaT
# 2217         2.285714  2.600789e+09       74.000000                NaT
#
#      confirmed_date released_date deceased_date     state  n_age
# 1        2020-01-30    2020-03-02           NaT  released   34.0
# 2        2020-01-30    2020-02-19           NaT  released   57.0
# 4        2020-01-31    2020-02-24           NaT  released   29.0
# 5        2020-01-31    2020-02-19           NaT  released   55.0
# 6        2020-01-31    2020-02-10           NaT  released   26.0
# ...             ...           ...           ...       ...    ...
# 2213     2020-03-16           NaT           NaT       NaN   31.0
# 2214     2020-02-20           NaT           NaT  isolated   23.0
# 2215     2020-02-22    2020-03-07           NaT  released   23.0
# 2216     2020-03-02    2020-03-15           NaT  released   49.0
# 2217     2020-03-04           NaT           NaT  isolated   47.0
#
# [2025 rows x 19 columns]

# %% [markdown]
# South Korea controlled the spread of Covid-19 pretty remarkably and has been commended for its scale and speed of testing, I assume that had to do with South Korean people getting tested almost immediately after they began feeling symptoms.
#
# So, I'm going to assume that the symptom_onset_date and confirmed_date are the same, as in they felt symptoms, got tested, and were confirmed all in the same day.

# %%
# Find and save in a variable the null symptom_onset_date index values
null_symptom_onset_date_indexes = df[df['symptom_onset_date'].isna()].index

# For each of those indexes of the null symptom_onset_dates, impute them with their respective confirmed_date dates
for idx in null_symptom_onset_date_indexes: df.at[idx, 'symptom_onset_date'] = df.at[idx, 'confirmed_date']

print('The count of non-null system_onset_date observations is now: {}'.format(df['symptom_onset_date'].notnull().sum()))
# Out:
# The count of non-null system_onset_date observations is now: 2218

# %%
print('The number of symptom_onset_date which equal confirmed_date is: {}'.format(df.query('symptom_onset_date == confirmed_date').shape[0]))
# Out:
# The number of symptom_onset_date which equal confirmed_date is: 2033

# %% [markdown]
# ### Handle the "released_date" column

# %% [markdown]
# The recommended quarantine time after having been confirmed with Covid-19 is 14 days, let's see if that holds true in our released_date feature

# %%
# I'll subtract the confirmed_date from the released_date to see what the difference in time is
released_minus_confirmed_dates = df['released_date'] - df['confirmed_date']

# Here I'll print descriptive statistics of those differences
released_minus_confirmed_dates[released_minus_confirmed_dates.notna()].describe()
# Out:
# count                           223
# mean     13 days 19:54:37.130044843
# std       5 days 04:04:37.041731209
# min                 1 days 00:00:00
# 25%                10 days 12:00:00
# 50%                13 days 00:00:00
# 75%                17 days 00:00:00
# max                32 days 00:00:00
# dtype: object

# %%
print('Here we see that the mean quarantine time was {}, or just about 14 days.'.format(released_minus_confirmed_dates[released_minus_confirmed_dates.notna()].mean()))
# Out:
# Here we see that the mean quarantine time was 13 days 19:54:37.130044843, or just about 14 days.

# %% [markdown]
# Knowing this, I'll impute the missing values with a 14 day difference from their respective confirmed_date.

# %%
# Impute the missing values with a 14 day difference from their respective confirmed_date
df['released_date'].fillna(df['confirmed_date'] + timedelta(days=14), inplace=True)

# %%
print('The new number of null release_date values is: {}'.format(df['released_date'].isna().sum()))
# Out:
# The new number of null release_date values is: 0

# %% [markdown]
# ### Handle the "deceased_date" column

# %%
df['deceased_date'].isna().sum()
# Out:
# 2186

# %% [markdown]
# That is a LOT of null values. But it's good that the vast majority are null, deceased_date is recorded only if people have died because of Covid-19.
#
# With that, I'll change the values here to either 1 or 0. If a death was recorded it will be changed to 1, and if not then 0.

# %%
# Find the index values of null and non-null values in deceased_date
deceased_null = df[df['deceased_date'].isna()].index
deceased_notnull = df[df['deceased_date'].notna()].index

# For each of those indexes, impute them with 0 or 1
for idx in deceased_null: df.at[idx, 'deceased_date'] = 0
for idx in deceased_notnull: df.at[idx, 'deceased_date'] = 1

# Change the datatype of deceased_date to integer
df['deceased_date'] = df['deceased_date'].astype(int)

# %%
df['deceased_date']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2213    0
# 2214    0
# 2215    0
# 2216    0
# 2217    0
# Name: deceased_date, Length: 2218, dtype: int32

# %% [markdown]
# ### Handle the "state" column

# %%
print('The number of null state values is: {}'.format(df['state'].isna().sum()))
# Out:
# The number of null state values is: 88

# %%
df['state'].value_counts()
# Out:
# isolated    1791
# released     307
# deceased      32
# Name: state, dtype: int64

# %%
# Do these null value observations share a few number of provinces?
df[df['state'].isna()]['province'].unique()
# Out:
# array(['Gyeonggi-do', 'Gyeongsangnam-do'], dtype=object)

# %% [markdown]
# I assume there was some clerical error in these observations not having recorded states. I'll simply impute "unknown" for these null values.

# %%
# Impute null values with "unknown"
df['state'].fillna('unknown', inplace=True)

# %%
print('The new number of null state values is: {}'.format(df['state'].isna().sum()))
# Out:
# The new number of null state values is: 0

# %% [markdown]
# ### Handle the "n_age" column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2218 entries, 0 to 2217
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          2218 non-null   int64
#  1   global_num          2218 non-null   float64
#  2   sex                 2218 non-null   object
#  3   birth_year          2218 non-null   float64
#  4   age                 1957 non-null   object
#  5   country             2218 non-null   object
#  6   province            2218 non-null   object
#  7   city                2218 non-null   object
#  8   disease             2218 non-null   int64
#  9   infection_case      2218 non-null   object
#  10  infection_order     2218 non-null   float64
#  11  infected_by         2218 non-null   float64
#  12  contact_number      2218 non-null   float64
#  13  symptom_onset_date  2218 non-null   datetime64[ns]
#  14  confirmed_date      2218 non-null   datetime64[ns]
#  15  released_date       2218 non-null   datetime64[ns]
#  16  deceased_date       2218 non-null   int32
#  17  state               2218 non-null   object
#  18  n_age               1764 non-null   float64
# dtypes: datetime64[ns](3), float64(6), int32(1), int64(2), object(7)
# memory usage: 320.7+ KB

# %%
print('The number of null n_age values is: {}'.format(df['n_age'].isna().sum()))
# Out:
# The number of null n_age values is: 454

# %%
# Find the null value indexes of n_age
nage_null_indexes = df[df['n_age'].isna()].index

# For each null n_age observation, impute it with the age based on today's year minus the birth_year
for idx in nage_null_indexes: df.at[idx, 'n_age'] = datetime.today().year - df.at[idx, 'birth_year']

print('The new number of null n_age values is: {}'.format(df['n_age'].isna().sum()))
# Out:
# The new number of null n_age values is: 0

# %% [markdown]
# ### Handle the "age" column

# %%
print('The number of null age values is: {}'.format(df['age'].isna().sum()))
# Out:
# The number of null age values is: 261

# %%
df['age'].unique()
# Out:
# array(['50s', '30s', '20s', '60s', '80s', '70s', '40s', '10s', '90s',
#        '0s', nan, '100s'], dtype=object)

# %%
# Create a function to convert age to decade
def convert_age_to_decade(age):
    '''Pass an age to return the decade version of that age. i.e. 33 ---> 30s'''
    
    return str((int(age) // 10) * 10) + 's'

# %%
# Find the null value indexes of age
age_null_indexes = df[df['age'].isna()].index

# For each null age, impute the decade version of the respective n_age
for idx in age_null_indexes: df.at[idx, 'age'] = convert_age_to_decade(df.at[idx, 'n_age'])
    
print('The new number of null age values is: {}'.format(df['age'].isna().sum()))
# Out:
# The new number of null age values is: 0

# %%
df['age'].unique()
# Out:
# array(['50s', '30s', '20s', '60s', '80s', '70s', '40s', '10s', '90s',
#        '0s', '100s'], dtype=object)

# %% [markdown]
# ### Now I'm going to convert current feature datatypes to more appropriate datatypes

# %%
features_to_int = ['birth_year','contact_number','n_age']
features_to_category = ['sex','age','country','province','city','infection_case','state']

for feature in features_to_category: df[feature] = df[feature].astype('category')
for feature in features_to_int: df[feature] = df[feature].astype(int)

# %%
df['infection_order'].value_counts()
# Out:
# 2.285714    2176
# 2.000000      19
# 1.000000      11
# 3.000000       6
# 5.000000       3
# 4.000000       2
# 6.000000       1
# Name: infection_order, dtype: int64

# %% [markdown]
#  **<font color='teal'> Check for any remaining null values.</font>**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2218 entries, 0 to 2217
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          2218 non-null   int64
#  1   global_num          2218 non-null   float64
#  2   sex                 2218 non-null   category
#  3   birth_year          2218 non-null   int32
#  4   age                 2218 non-null   category
#  5   country             2218 non-null   category
#  6   province            2218 non-null   category
#  7   city                2218 non-null   category
#  8   disease             2218 non-null   int64
#  9   infection_case      2218 non-null   category
#  10  infection_order     2218 non-null   float64
#  11  infected_by         2218 non-null   float64
#  12  contact_number      2218 non-null   int32
#  13  symptom_onset_date  2218 non-null   datetime64[ns]
#  14  confirmed_date      2218 non-null   datetime64[ns]
#  15  released_date       2218 non-null   datetime64[ns]
#  16  deceased_date       2218 non-null   int32
#  17  state               2218 non-null   category
#  18  n_age               2218 non-null   int32
# dtypes: category(7), datetime64[ns](3), float64(3), int32(4), int64(2)
# memory usage: 199.2 KB

# %%
df.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male        1964  50s   Korea    Seoul
# 1  1000000002         5.0    male        1987  30s   Korea    Seoul
# 2  1000000003         6.0    male        1964  50s   Korea    Seoul
# 3  1000000004         7.0    male        1991  20s   Korea    Seoul
# 4  1000000005         9.0  female        1992  20s   Korea    Seoul
#
#           city  disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu        0       overseas inflow              1.0  2.600789e+09
# 1  Jungnang-gu        0       overseas inflow              1.0  2.600789e+09
# 2    Jongno-gu        0  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu        0       overseas inflow              1.0  2.600789e+09
# 4  Seongbuk-gu        0  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# 0              75         2020-01-22     2020-01-23    2020-02-05
# 1              31         2020-01-30     2020-01-30    2020-03-02
# 2              17         2020-01-30     2020-01-30    2020-02-19
# 3               9         2020-01-26     2020-01-30    2020-02-15
# 4               2         2020-01-31     2020-01-31    2020-02-24
#
#    deceased_date     state  n_age
# 0              0  released     57
# 1              0  released     34
# 2              0  released     57
# 3              0  released     30
# 4              0  released     29

# %% [markdown]
# Remove date columns from the data.

# %%
df = df.drop(['symptom_onset_date','confirmed_date','released_date','deceased_date'],axis =1)

# %% [markdown]
# Review the count of unique values by column.

# %%
print(df.nunique())
# Out:
# patient_id         2218
# global_num         1304
# sex                   2
# birth_year           96
# age                  11
# country               4
# province             17
# city                137
# disease               2
# infection_case       16
# infection_order       7
# infected_by         207
# contact_number       72
# state                 4
# n_age                96
# dtype: int64

# %% [markdown]
# Review the percent of unique values by column.

# %%
print(df.nunique()/df.shape[0])
# Out:
# patient_id         1.000000
# global_num         0.587917
# sex                0.000902
# birth_year         0.043282
# age                0.004959
# country            0.001803
# province           0.007665
# city               0.061767
# disease            0.000902
# infection_case     0.007214
# infection_order    0.003156
# infected_by        0.093327
# contact_number     0.032462
# state              0.001803
# n_age              0.043282
# dtype: float64

# %% [markdown]
# Review the range of values per column.

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# patient_id       2218.0  4.014678e+09  2.192419e+09  1.000000e+09
# global_num       2218.0  4.664817e+03  2.211785e+03  1.000000e+00
# birth_year       2218.0  1.974786e+03  1.731583e+01  1.916000e+03
# disease          2218.0  8.566276e-03  9.217769e-02  0.000000e+00
# infection_order  2218.0  2.285714e+00  1.706622e-01  1.000000e+00
# infected_by      2218.0  2.600789e+09  7.216328e+08  1.000000e+09
# contact_number   2218.0  2.402390e+01  3.917145e+01  0.000000e+00
# n_age            2218.0  4.600902e+01  1.731123e+01  1.000000e+00
#
#                           25%           50%           75%           max
# patient_id       1.700000e+09  6.001000e+09  6.004000e+09  7.000000e+09
# global_num       4.205250e+03  4.664817e+03  5.900250e+03  8.717000e+03
# birth_year       1.965000e+03  1.974000e+03  1.988000e+03  2.020000e+03
# disease          0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# infection_order  2.285714e+00  2.285714e+00  2.285714e+00  6.000000e+00
# infected_by      2.600789e+09  2.600789e+09  2.600789e+09  6.113000e+09
# contact_number   2.400000e+01  2.400000e+01  2.400000e+01  1.160000e+03
# n_age            3.300000e+01  4.600000e+01  5.600000e+01  1.050000e+02

# %% [markdown]
# ### Check for duplicated rows

# %%
duplicateRowsDF = df[df.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, birth_year, age, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, state, n_age]
# Index: []

# %% [markdown]
# Print the categorical columns and their associated levels.

# %%
# I edited the code here from "include=['object']" to what it is now
dfo = df.select_dtypes(include=['category'], exclude=['datetime'])
dfo.shape
#get levels for all variables
vn = pd.DataFrame(dfo.nunique()).reset_index()
vn.columns = ['VarName', 'LevelsCount']
vn.sort_values(by='LevelsCount', ascending =False)
vn
# Out:
#           VarName  LevelsCount
# 0             sex            2
# 1             age           11
# 2         country            4
# 3        province           17
# 4            city          137
# 5  infection_case           16
# 6           state            4

# %% [markdown]
# **<font color='teal'> Plot the correlation heat map for the features.</font>**

# %%
plt.figure(figsize=[10,8])
sns.heatmap(df.corr(), vmin=-1, vmax=1, cmap='bwr', annot=True, fmt='.1f');

# %% [markdown]
# **<font color='teal'> Plot the boxplots to check for outliers. </font>**

# %%
df.columns
# Out:
# Index(['patient_id', 'global_num', 'sex', 'birth_year', 'age', 'country',
#        'province', 'city', 'disease', 'infection_case', 'infection_order',
#        'infected_by', 'contact_number', 'state', 'n_age'],
#       dtype='object')

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=[10,8])
sns.boxplot(y=df['global_num']);

# %%
plt.figure(figsize=[10,8])
sns.boxplot(y=df['birth_year']);

# %%
plt.figure(figsize=[10,8])
sns.boxplot(y=df['contact_number']);

# %%
plt.figure(figsize=[10,8])
sns.boxplot(y=df['n_age']);

# %% [markdown]
# ### Split the data into test and train subsamples

# %%
from sklearn.model_selection import train_test_split

# dont forget to define your X and y
X = df.drop(labels=['state'], axis=1)
y = df[['state']]

# %% [markdown]
# **<font color='teal'> Create dummy features for object type features. </font>**

# %%
X = pd.get_dummies(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=1)

# %% [markdown]
# ### Scale data to prep for model creation

# %%
#scale data
from sklearn import preprocessing
import numpy as np
# build scaler based on training data and apply it to test data to then also scale the test data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score
from sklearn.metrics import accuracy_score, log_loss

# %% [markdown]
# ### Fit Random Forest Classifier
# The fit model shows an overall accuracy of 80% which is great and indicates our model was effectively able to identify the status of a patients in the South Korea dataset.

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=300, random_state = 1,n_jobs=-1)
model_res = clf.fit(X_train_scaled, y_train)
y_pred = model_res.predict(X_test_scaled)
y_pred_prob = model_res.predict_proba(X_test_scaled)
lr_probs = y_pred_prob[:,1]
ac = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')
cm = confusion_matrix(y_test, y_pred)

print('Random Forest: Accuracy=%.3f' % (ac))

print('Random Forest: f1-score=%.3f' % (f1))
# Out:
# <ipython-input-94-103e381275aa>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_res = clf.fit(X_train_scaled, y_train)
# Random Forest: Accuracy=0.849
# Random Forest: f1-score=0.815

# %% [markdown]
# ### Create Confusion Matrix Plots
# Confusion matrices are great ways to review your model performance for a multi-class classification problem. Being able to identify which class the misclassified observations end up in is a great way to determine if you need to build additional features to improve your overall model. In the example below we plot a regular counts confusion matrix as well as a weighted percent confusion matrix. The percent confusion matrix is particulary helpful when you have unbalanced class sizes.

# %%
class_names=['isolated','released','unknown','deceased'] # name  of classes

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
#plt.savefig('figures/RF_cm_multi_class.png')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
#plt.savefig('figures/RF_cm_proportion_multi_class.png', bbox_inches="tight")
plt.show()
# Out:
# Confusion matrix, without normalization
# [[  6   1   0   0]
#  [  0 344   7   0]
#  [  0  56  13   0]
#  [  0   3   0  14]]
# Normalized confusion matrix
# [[0.86 0.14 0.   0.  ]
#  [0.   0.98 0.02 0.  ]
#  [0.   0.81 0.19 0.  ]
#  [0.   0.18 0.   0.82]]

# %% [markdown]
# ### Plot feature importances
# The random forest algorithm can be used as a regression or classification model. In either case it tends to be a bit of a black box, where understanding what's happening under the hood can be difficult. Plotting the feature importances is one way that you can gain a perspective on which features are driving the model predictions.

# %%
feature_importance = clf.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(10,10))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# 30

# %% [markdown]
# The popularity of random forest is primarily due to how well it performs in a multitude of data situations. It tends to handle highly correlated features well, where as a linear regression model would not. In this case study we demonstrate the performance ability even with only a few features and almost all of them being highly correlated with each other.
# Random Forest is also used as an efficient way to investigate the importance of a set of features with a large data set. Consider random forest to be one of your first choices when building a decision tree, especially for multiclass classifications.
